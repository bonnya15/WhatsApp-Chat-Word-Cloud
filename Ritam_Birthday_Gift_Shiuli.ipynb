theke berobii\n22/09/19, 10:19 Hmm..\n22/09/19, 10:20 Uber e jabo\n22/09/19, 10:20 Chap nei.\n22/09/19, 10:20  - Rit Jio: Se jatei jas age berobi, okhane gie bose ba darie thakbi dorkar hole\n22/09/19, 10:22 Hmm\n22/09/19, 10:26  - Rit Jio: Ar aj rat jagbi na, ghum hochhe na baalbichi jai hok, rat e alo jivie chokh bondho kore sue thakbi\n22/09/19, 10:26  - Rit Jio: Ghum na ele, more jaoar natok korbi\n22/09/19, 10:28 Hmm\n22/09/19, 10:37 It is hard for logic to prevail over emotion.\n22/09/19, 10:38  - Rit Jio: Ar hya gandu to tui, abar bolbi ekhn ke mone korai, admit card dekhe ja ja nie jaoa dorkar nie jas\n22/09/19, 10:38  - Rit Jio: Dher baal\n22/09/19, 10:38 Ha. Nie sui\n22/09/19, 10:38 Chap nei\n22/09/19, 10:38 Guchie nebo\n22/09/19, 10:38 Pencil rubber kine niechi\n22/09/19, 10:39  - Rit Jio: Ok\n22/09/19, 10:39 Chap\n22/09/19, 10:39 Bohut chap\n22/09/19, 10:39  - Rit Jio: Hya biriyani kine eksathe kheye ne\n22/09/19, 10:40 Khide pacche.\n22/09/19, 10:40 Dhur baal\n22/09/19, 10:40 Valo Lage na\n22/09/19, 10:41  - Rit Jio: Ma ke bol\n22/09/19, 10:41 Ma nei\n22/09/19, 10:42  - Rit Jio: Baba ke bol\n22/09/19, 10:42 Baba ghumocche\n22/09/19, 10:42  - Rit Jio: Order de\n22/09/19, 10:42 Sala.  Poesa to g ...

# %%
import re

x=re.sub("\d\d?/\d\d?/\d\d,\s\d\d?:\d\d"," ",txt)
x = re.sub(r' - Rit Jio: .*','',txt)

values=x.splitlines()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
  

  
comment_words = ''
stopwords = set(STOPWORDS)
print(stopwords)
  
# iterate through the csv file
for val in values:
      
    # typecaste each val to string
    val = str(val)
  
    # split the value
    tokens = val.split()
      
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
  
# plot the WordCloud image                       
plt.figure(figsize = (12, 12), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.savefig('plot.png', dpi=300, bbox_inches='tight')  
plt.show()
# Out:
# {'so', "you'd", "shouldn't", "when's", 'she', "doesn't", 'further', 'them', 'my', 'have', 'theirs', 'r', 'an', 'is', 'that', 'they', 'no', 'since', "we'd", 'there', "we've", 'its', 'how', "i've", 'until', "you're", "i'll", 'again', 'more', "you've", 'only', "he'd", 'those', 'has', 'if', 'com', "they're", 'while', 'into', "she'd", "he's", 'below', 'k', 'of', 'such', 'you', 'just', 'all', 'other', 'by', 'itself', 'before', 'or', "where's", 'a', 'am', 'each', "it's", 'off', 'yourselves', 'with', 'some', 'once', 'themselves', 'not', 'own', "why's", 'would', 'then', 'www', 'these', "mustn't", 'very', 'few', "they've", 'nor', 'shall', 'myself', 'up', 'otherwise', 'for', "hasn't", 'out', 'ours', 'what', "hadn't", "won't", "isn't", 'because', "aren't", 'were', "she'll", 'yours', 'at', 'had', 'else', 'when', 'why', 'does', 'the', 'their', 'himself', 'where', 'ought', "don't", 'this', 'it', 'to', 'having', 'over', "who's", 'on', 'we', 'between', "i'd", 'however', "that's", 'whom', 'also', 'our', 'be', 'could', 'against', 'get', 'her', 'ourselves', 'are', 'above', "wasn't", 'both', 'too', "you'll", 'been', 'during', "i'm", 'did', 'your', 'after', "we'll", 'but', 'ever', "let's", "haven't", 'i', "she's", 'cannot', "he'll", 'any', 'than', 'yourself', 'him', "here's", "there's", 'was', 'about', 'do', 'he', 'down', "shan't", 'being', 'hers', "couldn't", 'which', 'same', 'under', "what's", 'me', 'in', 'through', 'his', "didn't", "can't", "they'll", "weren't", "they'd", 'herself', "we're", 'as', "how's", 'who', 'like', "wouldn't", 'can', 'most', 'http', 'from', 'here', 'and', 'doing', 'should'}
