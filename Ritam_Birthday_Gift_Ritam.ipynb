# %%
f=open('chat.txt',encoding='utf-8')
txt=f.read()
f.close()

# %%
txt=txt.replace(" - Ritam Jio: ","")
txt=txt.replace("am","")
txt=txt.replace("pm","")
txt=txt.replace("<Media omitted>","")

# %%
txt
# Out:
# '21/09/19, 8:28 Ei ebullient mane i jani na\n21/09/19, 8:29  - Shiuli Subhra Ghosh: Okay.. not of your need.\n21/09/19, 8:29 I always dont want to learn things for need\n21/09/19, 8:30  - Shiuli Subhra Ghosh: Okay.. I misconstrued your self.\n21/09/19, 8:30  - Shiuli Subhra Ghosh: Google is your best buddy.. ask her.\n21/09/19, 8:31 I already did, cazz\n21/09/19, 8:33  - Shiuli Subhra Ghosh: Such celerity..\n21/09/19, 8:33 Always\n21/09/19, 8:35  - Shiuli Subhra Ghosh: I may be little brusque.. but your unseemly behaviour is sometimes stinging..\n21/09/19, 8:37 Glad to hear that\n21/09/19, 8:43  - Shiuli Subhra Ghosh: Don\'t dare to be extreme sycophantic.\n21/09/19, 8:43  - Shiuli Subhra Ghosh: 😒😒😒\n21/09/19, 8:45 Dare?\n21/09/19, 8:45 As if..\n21/09/19, 8:46 I will do whatever I wanna do\n21/09/19, 8:46 I will be whatever I wanna be\n21/09/19, 8:50  - Shiuli Subhra Ghosh: Nice.\n21/09/19, 9:00 Ranna korchhi, pore bokbo\n21/09/19, 9:03  - Shiuli Subhra Ghosh: Bokte hobe na\n21/09/19, 9:03  - Shiuli Subhra Ghosh: Ek din o dekha kore ne je chele tar kotha Bolte hobe na\n21/09/19, 9:04 Sune niechhi, ebar baal chher\n21/09/19, 9:13  - Shiuli Subhra Ghosh: Sala\n21/09/19, 9:13  - Shiuli Subhra Ghosh: Gandu\n21/09/19, 9:13  - Shiuli Subhra Ghosh: Pagla choda.\n21/09/19, 9:31 Bole ja\n21/09/19, 9:32  - Shiuli Subhra Ghosh: Amar kaj ache.\n21/09/19, 9:32  - Shiuli Subhra Ghosh: Tor Moto ranna kora Amar kaj na.\n21/09/19, 10:05  - Shiuli Subhra Ghosh: Btw..\n21/09/19, 10:05  - Shiuli Subhra Ghosh: Ki ranna korli?\n21/09/19, 10:20 Chilli chicken\n21/09/19, 11:07  - Shiuli Subhra Ghosh: Mayer sahajyo Nie na chara?\n21/09/19, 11:11  - Shiuli Subhra Ghosh: Aj madhuporko Nie el\n21/09/19, 11:11  - Shiuli Subhra Ghosh: Chittaranjan theke\n22/09/19, 12:34  - Shiuli Subhra Ghosh: Saradin ghumieo ekhono ghumocchs?\n22/09/19, 8:02 Hya kal sokalei boll to saradin ghumobo\n22/09/19, 8:03 Kheye deye ichhe holo, ekta calpol kheye ghumie porl\n22/09/19, 8:04  - Shiuli Subhra Ghosh: 😒😒\n22/09/19, 9:32  - Shiuli Subhra Ghosh: Good morning o bole na\n22/09/19, 9:41 Boll\n22/09/19, 10:14  - Shiuli Subhra Ghosh: Dekhl\n22/09/19, 10:15 Pore chodabi\n22/09/19, 10:15 Tor center kothai kal?\n22/09/19, 10:16  - Shiuli Subhra Ghosh: Salt Lake sec 5\n22/09/19, 10:16 12 ta theke to?\n22/09/19, 10:16  - Shiuli Subhra Ghosh: Nah to\n22/09/19, 10:16  - Shiuli Subhra Ghosh: 8:30 theke\n22/09/19, 10:16 Oh onek age berobi\n22/09/19, 10:17 Atleast doa 1 ghonta age\n22/09/19, 10:17  - Shiuli Subhra Ghosh: Hmm\n22/09/19, 10:17 At least\n22/09/19, 10:17  - Shiuli Subhra Ghosh: 7 tar age berie jabo\n22/09/19, 10:17 Karon rasta ghat bhalo na\n22/09/19, 10:17  - Shiuli Subhra Ghosh: Rastar ki holo?\n22/09/19, 10:18 Mane ultodanga i bisal j hoi\n22/09/19, 10:18 Oi bridge tridge er jonyo\n22/09/19, 10:18 Na hole bhalo kotha\n22/09/19, 10:18 Kintu berobi age bhage\n22/09/19, 10:18  - Shiuli Subhra Ghosh: Hmm\n22/09/19, 10:18  - Shiuli Subhra Ghosh: Sokaler dike mostly thake na\n22/09/19, 10:18  - Shiuli Subhra Ghosh: R Ami 6 tae uthe jabo\n22/09/19, 10:18 Toke oto vabte hbe na -_-\n22/09/19, 10:18  - Shiuli Subhra Ghosh: Ja tension ghum hocche na\n22/09/19, 10:19 Se tui jokhoni uthis baal chhiris, soa 7 ta theke sare 7 tar modhye bari theke berobii\n22/09/19, 10:19  - Shiuli Subhra Ghosh: Hmm..\n22/09/19, 10:20  - Shiuli Subhra Ghosh: Uber e jabo\n22/09/19, 10:20  - Shiuli Subhra Ghosh: Chap nei.\n22/09/19, 10:20 Se jatei jas age berobi, okhane gie bose ba darie thakbi dorkar hole\n22/09/19, 10:22  - Shiuli Subhra Ghosh: Hmm\n22/09/19, 10:26 Ar aj rat jagbi na, ghum hochhe na baalbichi jai hok, rat e alo jivie chokh bondho kore sue thakbi\n22/09/19, 10:26 Ghum na ele, more jaoar natok korbi\n22/09/19, 10:28  - Shiuli Subhra Ghosh: Hmm\n22/09/19, 10:37  - Shiuli Subhra Ghosh: It is hard for logic to prevail over emotion.\n22/09/19, 10:38 Ar hya gandu to tui, abar bolbi ekhn ke mone korai, admit card dekhe ja ja nie jaoa dorkar nie jas\n22/09/19, 10:38 Dher baal\n22/09/19, 10:38  ...

# %%
import re

x=re.sub("\d\d?/\d\d?/\d\d,\s\d\d?:\d\d"," ",txt)
x = re.sub(r' - Shiuli Subhra Ghosh: .*','',txt)

values=x.splitlines()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
  

  
comment_words = ''
stopwords = set(STOPWORDS)
print(stopwords)
  
# iterate through the csv file
for val in values:
      
    # typecaste each val to string
    val = str(val)
  
    # split the value
    tokens = val.split()
      
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
  
# plot the WordCloud image                       
plt.figure(figsize = (12, 12), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.savefig('plot.png', dpi=300, bbox_inches='tight')  
plt.show()
# Out:
# {'myself', 'from', "we're", 'what', "you've", 'other', 'your', "i'll", 'here', 'have', 'a', 'he', 'same', "they're", "doesn't", "you'd", 'against', "can't", 'just', 'you', "isn't", 'ourselves', "haven't", 'be', 'or', 'at', "he'd", 'being', "won't", 'would', 'www', 'that', 'me', 'since', 'his', 'could', 'off', 'himself', "it's", "she's", 'theirs', 'shall', "you're", 'itself', "weren't", 'else', "mustn't", 'own', 'and', "they'd", 'are', "they'll", "i'd", "hasn't", "how's", 'no', "don't", 'it', 'for', "wouldn't", 'in', "they've", 'my', 'were', 'when', 'get', 'not', "shouldn't", 'those', 'very', "who's", 'which', 'once', 'why', 'ought', "shan't", 'then', 'with', 'by', 'nor', 'otherwise', 'yourselves', 'they', 'yourself', 'most', "couldn't", 'but', 'ever', "she'll", 'them', 'can', 'if', 'only', "there's", 'however', 'http', 'so', 'like', 'while', 'whom', "didn't", 'him', 'about', "here's", 'too', 'was', 'again', 'during', 'into', "hadn't", 'all', "where's", 'com', 'some', 'between', 'on', 'the', 'is', 'r', 'through', "let's", 'k', 'does', 'has', 'up', 'this', 'we', "we've", 'how', "why's", 'am', 'she', 'before', 'an', "he's", 'do', 'did', 'both', 'further', 'hers', "she'd", "i've", 'few', 'any', 'i', 'having', 'its', "he'll", 'more', 'below', 'out', 'of', "wasn't", "when's", 'themselves', "you'll", 'had', 'where', 'who', 'under', 'each', 'our', "aren't", 'doing', "i'm", 'after', 'such', "that's", 'to', 'their', 'should', 'until', "what's", 'yours', "we'll", 'cannot', 'herself', 'because', 'over', 'as', 'been', 'above', 'there', "we'd", 'than', 'also', 'down', 'these', 'her', 'ours'}
